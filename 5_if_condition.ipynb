# %% [markdown]
# <a href="https://colab.research.google.com/github/niteshsah3424/HOME_PYTHON/blob/main/5_if_condition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# if conditions

# %%
#1.wap to check whether the persion eligible to vote or not

age=int(input("enter the age"))

if age >18:
  print("you are eligible for vote")
# Out:
# enter the age22
# you are eligible for vote

# %%
#2.wap to check character is vowel or not

char=input('enter a character')

if char in'aeiouAEIOU':
  print(char," char is vowel")
# Out:
# enter a charactera
# a  char is vowel

# %%
#3.wap to check character is consonat or not

char=input("enter the character")

if char not in 'aeiouAEIOU':
  print(char,"char is consonant")
# Out:
# enter the characterk
# k char is consonant

# %%
#4.wap to check whethe even ot not

num=int(input("enter the num"))

if num%2==0:
  print("even number")
# Out:
# enter the num4
# even number

# %%
#5.wap to check whethe the given data is flaot or not

num=eval(input("enter the number"))

if type(num)==float:
  print("number is float data type")
# Out:
# enter the number22.33
# number is float data type

# %%
#6.wap to check whether data is mutable or not
#mutable--->(list,set,dict)

data=eval(input("enter the number"))

if type(data) in [set,list,dict]:
  print("mutuble data type")
# Out:
# enter the number[1,2,3,4]
# mutuble data type

# %%
#7.wap to check whether a character is upprcase or not
char=input("enter the character")

if 'A'<=char<='Z':
  print("upper case")
# Out:
# enter the characterD
# upper case

# %%
#8.Wap to check whether the character is lower case or not

char=input("enter the character")

if'a'<=char<='z':
  print("lower case")
# Out:
# enter the characterg
# lower case

# %%
#9.wap to chek whether a character is digit or not

num=input("enter the number")

if '0'<=num<='9':
  print("num is the digit")
# Out:
# enter the number100
# numb is the digit

# %%
#10.chek whether the character is special character or not
#special character=@#%$

char=input("enter the character")

if not  'A'<= char <='Z' or 'a'<=char<='z' or '0'<=char<='9':
  print("special character")
# Out:
# enter the character@
# special character
