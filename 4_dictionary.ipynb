# %% [markdown]
# <a href="https://colab.research.google.com/github/niteshsah3424/HOME_PYTHON/blob/main/4_dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#dictionary
dict1={1:'apple',2:'ball',3:'cat'}

# print(dict1)

print(type(dict1))

dict1[4]='dog'
print(dict1)

dict1[4]='egg'
print(dict1)

.....printing.......

print(dict1.keys())
print(dict1.values())
print(dict1.items())

#....removing.......

print(dict1.pop(3))
print(dict1)


print(dict1.popitem())
print(dict1)
# Out:
# cat
# {1: 'apple', 2: 'ball'}
# (2, 'ball')
# {1: 'apple'}
