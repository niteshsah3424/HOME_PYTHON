# %% [markdown]
# <a href="https://colab.research.google.com/github/niteshsah3424/HOME_PYTHON/blob/main/3_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#set

st={1,2,3,4}
print(st)
print(type(st))
st.add(9)
print(st)

# .........inbuild function............


st.add(4)---# aready in the set ...so can show bcz it canot sore duplicate
print(st)

st.remove(4)#revove the specific value
print(st)

st.pop()
print(st)
# Out:
# {1, 2, 3}
# {2, 3}

# %%
#1.Add a new element to an existing set.
st={1,2,3,4,5}

st.add(8)
print(st)
# Out:
# {1, 2, 3, 4, 5, 8}

# %%
#2.wap to remove a  elemet

st={1,2,3,4,5,6,78}
st.remove(78)
print(st)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
# discard
s = {1, 2, 3}
s.discard(3)
print(s)
# Out:
# {1, 2}

# %%
#4.union of two set
a = {1, 2, 3}
b = {3, 4, 5}
print(a.union(b))
# Out:
# {1, 2, 3, 4, 5}

# %%
#5.intersection
a = {1, 2, 3}
b = {2, 3, 4}
print(a.intersection(b))
# Out:
# {2, 3}
